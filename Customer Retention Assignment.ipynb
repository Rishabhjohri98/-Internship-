# %%
# For importing neccessary libraries for EDA purposes:-
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# For reading file in jupyter notebook
data=pd.read_excel("customer_retention_dataset.xlsx")

# %%
# For fetching data from dataset:-
data
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS( EDA):-

# %%
# For checking the rows and columns present in the dataset
data.shape
# Out:
# (269, 71)

# %%
# For checking the Null/NaN values in the dataset:-
data.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %% [markdown]
# Here as checked above, there are no Null values prsent in that dataset.

# %%
# For checking the information of dataset:
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %%
# For checking the datatypes of each columns in dataset:-
data.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %% [markdown]
# Here, as seen data has mostly object datatypes.

# %%
# For checking the statistical summary of the dataset:
data.describe()
# Out:
#        4 What is the Pin Code of where you shop online from?
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# max                                        560037.000000

# %%
# For seeing the available columns in the dataset:
data.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
# For checking the unique values present in the dataset:
data.nunique()
# Out:
# 1Gender of respondent                                                    2
# 2 How old are you?                                                       5
# 3 Which city do you shop online from?                                   11
# 4 What is the Pin Code of where you shop online from?                   39
# 5 Since How Long You are Shopping Online ?                               5
#                                                                         ..
# Longer delivery period                                                   6
# Change in website/Application design                                     7
# Frequent disruption when moving from one page to another                 8
# Website is as efficient as before                                        8
# Which of the Indian online retailer would you recommend to a friend?     8
# Length: 71, dtype: int64

# %%
# For checking the missing values present in the dataset:
Missingvalue=[feature for feature in data.columns if data[feature].isnull().sum()>1]

# %%
Missingvalue
# Out:
# []

# %% [markdown]
# Here, there are null missing values present in the dataset.

# %%
# For checking the number of numerical features:
NumericalFeature=[feature for feature in data.columns if data[feature].dtypes!="O"]

# %%
NumericalFeature
# Out:
# ['4 What is the Pin Code of where you shop online from?']

# %%
# For displaying the number of continuos features
print(len(NumericalFeature))
# Out:
# 1

# %% [markdown]
# So, here there are only 1 numerical feature available in dataset and rest all are may be object.

# %%
# For checking the unique values and the number of unique outcomes in the continuos data columns:-
data[NumericalFeature].nunique()
# Out:
# 4 What is the Pin Code of where you shop online from?    39
# dtype: int64

# %%
# For checking the categorical feature and discrete columns:-
discreteFeature=[feature for feature in data.columns if feature not in NumericalFeature]

# %%
data[discreteFeature]
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %% [markdown]
# Here, as seen above there ae 70 discrete columns in this dataset.

# %%
plt.figure(figsize=(8,6))
print(data['1Gender of respondent'].value_counts())
print("-"*70)

sns.countplot(data['1Gender of respondent'].sort_values())
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='count'>

# %% [markdown]
# Here, there are 181 Females and 88 Males.

# %%
# For checking the distribution between How old people are?
plt.figure(figsize=(8,6))
print(data['2 How old are you? '].value_counts())
print("-"*70)
sns.countplot(data['2 How old are you? '].sort_values())
# Out:
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64
# ----------------------------------------------------------------------
# <AxesSubplot:xlabel='2 How old are you? ', ylabel='count'>

# %%
# For checking distribution among columns:
plt.figure(figsize=(14,8))
print(data['3 Which city do you shop online from?'].value_counts())
print("-"*70)
sns.countplot(data['3 Which city do you shop online from?'].sort_values())
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='3 Which city do you shop online from?', ylabel='count'>

# %%
# For checking distribution among columns:
plt.figure(figsize=(10,6))
print(data['5 Since How Long You are Shopping Online ?'].value_counts())
print("-"*70)
sns.countplot(data['5 Since How Long You are Shopping Online ?'].sort_values(),palette="Set1")
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='5 Since How Long You are Shopping Online ?', ylabel='count'>

# %%
# For checking distribution among columns
plt.figure(figsize=(14,6))
print(data['7 How do you access the internet while shopping on-line?'].value_counts())
print("-"*70)
sns.countplot(data['7 How do you access the internet while shopping on-line?'].sort_values(),palette="Set2")
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='7 How do you access the internet while shopping on-line?', ylabel='count'>

# %%
# For checking distribution among columns:
plt.figure(figsize=(10,6))
print(data['8 Which device do you use to access the online shopping?'].value_counts())
print("-"*70)
sns.countplot(data['8 Which device do you use to access the online shopping?'].sort_values())
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: 8 Which device do you use to access the online shopping?, dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='8 Which device do you use to access the online shopping?', ylabel='count'>

# %%
# For checking distribution among columns:

plt.figure(figsize=(10,6))
print(data['How much time do you explore the e- retail store before making a purchase decision?'].value_counts())
print("-"*70)
sns.countplot(data['How much time do you explore the e- retail store before making a purchase decision?'].sort_values())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'How much time do you explore the e- retail store before making a purchase decision?'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
plt.figure(figsize=(6,6))
print(data['15 What is your preferred payment Option?'].value_counts())
print("-"*70)
sns.countplot(data['15 What is your preferred payment Option?'].sort_values(),palette="Set3")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '15 What is your preferred payment Option?'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
plt.figure(figsize=(6,6))
print(data['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?'].value_counts())
print("-"*70)
sns.countplot(data['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?'].sort_values(),palette=None)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?'
#
# ...

# %%
plt.figure(figsize=(13,8))
print(data['18 The content on the website must be easy to read and understand'].value_counts())
print("-"*70)
sns.countplot(data['18 The content on the website must be easy to read and understand'].sort_values(),palette="Set2")
# Out:
# Strongly agree (5)       164
# Agree (4)                 80
# Strongly disagree (1)     18
# Indifferent (3)            7
# Name: 18 The content on the website must be easy to read and understand, dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='18 The content on the website must be easy to read and understand', ylabel='count'>

# %%
# For checking distribution among different categorical columns:
plt.figure(figsize=(8,8))
print(data['20 Complete information on listed seller and product being offered is important for purchase decision.'].value_counts())
print("-"*70)
sns.countplot(data['20 Complete information on listed seller and product being offered is important for purchase decision.'].sort_values(),palette=None)
# Out:
# Agree (4)                101
# Strongly agree (5)        87
# Indifferent (3)           52
# Dis-agree (2)             18
# Strongly disagree (1)     11
# Name: 20 Complete information on listed seller and product being offered is important for purchase decision., dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='20 Complete information on listed seller and product being offered is important for purchase decision.', ylabel='count'>

# %%
# For checking distribution among different categorical columns:
plt.figure(figsize=(8,8))
print(data['21 All relevant information on listed products must be stated clearly'].value_counts())
print("-"*70)
sns.countplot(data['21 All relevant information on listed products must be stated clearly'].sort_values(),palette="Set1")
# Out:
# Agree (4)                132
# Strongly agree (5)       107
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Name: 21 All relevant information on listed products must be stated clearly, dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='21 All relevant information on listed products must be stated clearly', ylabel='count'>

# %%
# For checking distribution among different categorical columns:
plt.figure(figsize=(8,8))
print(data['22 Ease of navigation in website'].value_counts())
print("-"*70)
sns.countplot(data['22 Ease of navigation in website'].sort_values(),palette="Set2")
# Out:
# Strongly agree (5)       141
# Agree (4)                105
# Strongly disagree (1)     18
# Dis-agree (2)              5
# Name: 22 Ease of navigation in website, dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='22 Ease of navigation in website', ylabel='count'>

# %%
# For checking distribution among different categorical columns:
plt.figure(figsize=(10,10))
print(data['23 Loading and processing speed'].value_counts())
print("-"*70)
sns.countplot(data['23 Loading and processing speed'].sort_values(),palette="Set3")
# Out:
# Strongly agree (5)       115
# Agree (4)                112
# Dis-agree (2)             18
# Strongly disagree (1)     12
# Indifferent (3)           12
# Name: 23 Loading and processing speed, dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='23 Loading and processing speed', ylabel='count'>

# %%
# For checking distribution among different categorical columns:
plt.figure(figsize=(8,8))
print(data['24 User friendly Interface of the website'].value_counts())
print("-"*70)
sns.countplot(data['24 User friendly Interface of the website'].sort_values(),palette=None)
# Out:
# Strongly agree (5)       189
# Agree (4)                 45
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Indifferent (3)            5
# Name: 24 User friendly Interface of the website, dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='24 User friendly Interface of the website', ylabel='count'>

# %%
# For checking distribution among different categorical columns:
plt.figure(figsize=(6,8))
print(data['25 Convenient Payment methods'].value_counts())
print("-"*70)
sns.countplot(data['25 Convenient Payment methods'].sort_values(),palette="Set1")
# Out:
# Strongly agree (5)    159
# Agree (4)              80
# Dis-agree (2)          30
# Name: 25 Convenient Payment methods, dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='25 Convenient Payment methods', ylabel='count'>

# %%
# For checking distribution among different categorical columns:
plt.figure(figsize=(8,8))
print(data['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'].value_counts())
print("-"*70)
sns.countplot(data['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'].sort_values(),palette="Set2")
# Out:
# Strongly agree (5)    141
# Agree (4)              86
# Disagree (2)           30
# indifferent  (3)       12
# Name: 26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time, dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time', ylabel='count'>

# %%
# For checking distribution among different categorical columns:
plt.figure(figsize=(8,8))
print(data['27 Empathy (readiness to assist with queries) towards the customers'].value_counts())
print("-"*70)
sns.countplot(data['27 Empathy (readiness to assist with queries) towards the customers'].sort_values(),palette="Set3")
# Out:
# Strongly agree (5)       194
# Agree (4)                 42
# Strongly disagree (1)     18
# indifferent (3)           15
# Name: 27 Empathy (readiness to assist with queries) towards the customers, dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='27 Empathy (readiness to assist with queries) towards the customers', ylabel='count'>

# %%
# For checking distribution among different categorical columns:
plt.figure(figsize=(6,8))
print(data['28 Being able to guarantee the privacy of the customer'].value_counts())
print("-"*70)
sns.countplot(data['28 Being able to guarantee the privacy of the customer'].sort_values(),palette=None)
# Out:
# Strongly agree (5)    185
# Agree (4)              58
# indifferent (3)        26
# Name: 28 Being able to guarantee the privacy of the customer, dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='28 Being able to guarantee the privacy of the customer', ylabel='count'>

# %%
# For checking distribution among different categorical columns:
plt.figure(figsize=(8,8))
print(data['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'].value_counts())
print("-"*70)
sns.countplot(data['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'].sort_values(),palette="Set1")
# Out:
# Strongly agree (5)       149
# Agree (4)                 94
# indifferent (3)           15
# Strongly disagree (1)     11
# Name: 29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.), dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)', ylabel='count'>

# %%
# For checking distribution among different categorical columns:
plt.figure(figsize=(8,8))
print(data['30 Online shopping gives monetary benefit and discounts'].value_counts())
print("-"*70)
sns.countplot(data['30 Online shopping gives monetary benefit and discounts'].sort_values(),palette="Set2")
# Out:
# Strongly agree (5)       105
# Agree (4)                 85
# indifferent (3)           50
# Strongly disagree (1)     18
# Dis-agree (2)             11
# Name: 30 Online shopping gives monetary benefit and discounts, dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='30 Online shopping gives monetary benefit and discounts', ylabel='count'>

# %%
# For checking distribution among different categorical columns:
plt.figure(figsize=(10,10))
print(data['31 Enjoyment is derived from shopping online'].value_counts())
print("-"*70)
sns.countplot(data['31 Enjoyment is derived from shopping online'].sort_values(),palette="Set3")
# Out:
# Strongly agree (5)       86
# indifferent (3)          75
# Agree (4)                59
# Strongly disagree (1)    30
# Dis-agree (2)            19
# Name: 31 Enjoyment is derived from shopping online, dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='31 Enjoyment is derived from shopping online', ylabel='count'>

# %%
# For checking distribution among different categorical columns:
plt.figure(figsize=(8,8))
print(data['32 Shopping online is convenient and flexible'].value_counts())
print("-"*70)
sns.countplot(data['32 Shopping online is convenient and flexible'].sort_values(),palette=None)
# Out:
# Strongly agree (5)    146
# Agree (4)              78
# indifferent (3)        33
# Dis-agree (2)          12
# Name: 32 Shopping online is convenient and flexible, dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='32 Shopping online is convenient and flexible', ylabel='count'>

# %%
# For checking distribution among different categorical columns:
plt.figure(figsize=(6,7))
print(data['33 Return and replacement policy of the e-tailer is important for purchase decision'].value_counts())
print("-"*70)
sns.countplot(data['33 Return and replacement policy of the e-tailer is important for purchase decision'].sort_values(),palette="Set1")
# Out:
# Strongly agree (5)    198
# Agree (4)              51
# Dis-agree (2)          20
# Name: 33 Return and replacement policy of the e-tailer is important for purchase decision, dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='33 Return and replacement policy of the e-tailer is important for purchase decision', ylabel='count'>

# %%
# For checking distribution among different categorical columns:
plt.figure(figsize=(8,8))
print(data['34 Gaining access to loyalty programs is a benefit of shopping online'].value_counts())
print("-"*70)
sns.countplot(data['34 Gaining access to loyalty programs is a benefit of shopping online'].sort_values(),palette="Set2")
# Out:
# Strongly agree (5)       115
# Agree (4)                 64
# indifferent (3)           64
# Dis-agree (2)             15
# Strongly disagree (1)     11
# Name: 34 Gaining access to loyalty programs is a benefit of shopping online, dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='34 Gaining access to loyalty programs is a benefit of shopping online', ylabel='count'>

# %%
# For checking distribution among different categorical columns:
plt.figure(figsize=(8,8))
print(data['35 Displaying quality Information on the website improves satisfaction of customers'].value_counts())
print("-"*70)
sns.countplot(data['35 Displaying quality Information on the website improves satisfaction of customers'].sort_values(),palette="Set3")
# Out:
# Strongly agree (5)    133
# Agree (4)              80
# indifferent (3)        56
# Name: 35 Displaying quality Information on the website improves satisfaction of customers, dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='35 Displaying quality Information on the website improves satisfaction of customers', ylabel='count'>

# %%
# For checking distribution among different categorical columns:
plt.figure(figsize=(8,7))
print(data['36 User derive satisfaction while shopping on a good quality website or application'].value_counts())
print("-"*70)
sns.countplot(data['36 User derive satisfaction while shopping on a good quality website or application'].sort_values(),palette="Set1")
# Out:
# Strongly agree (5)    175
# Agree (4)              86
# Dis-agree (2)           8
# Name: 36 User derive satisfaction while shopping on a good quality website or application, dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='36 User derive satisfaction while shopping on a good quality website or application', ylabel='count'>

# %%
# For checking distribution among different categorical columns:
plt.figure(figsize=(10,10))
print(data['37 Net Benefit derived from shopping online can lead to users satisfaction'].value_counts())
print("-"*70)
sns.countplot(data['37 Net Benefit derived from shopping online can lead to users satisfaction'].sort_values(),palette="Set2")
# Out:
# Strongly agree (5)    164
# Agree (4)              54
# indifferent (3)        40
# Dis-agree (2)          11
# Name: 37 Net Benefit derived from shopping online can lead to users satisfaction, dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='37 Net Benefit derived from shopping online can lead to users satisfaction', ylabel='count'>

# %%
# For checking distribution among different categorical columns:
plt.figure(figsize=(8,7))
print(data['42 The Convenience of patronizing the online retailer'].value_counts())
print("-"*70)
sns.countplot(data['42 The Convenience of patronizing the online retailer'].sort_values(),palette="Set3")
# Out:
# Agree (4)             138
# indifferent (3)        77
# Strongly agree (5)     54
# Name: 42 The Convenience of patronizing the online retailer, dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='42 The Convenience of patronizing the online retailer', ylabel='count'>

# %%
# For checking distribution among different categorical columns:
plt.figure(figsize=(8,8))
print(data['43 Shopping on the website gives you the sense of adventure'].value_counts())
print("-"*70)
sns.countplot(data['43 Shopping on the website gives you the sense of adventure'].sort_values(),palette=None)
# Out:
# Agree (4)                101
# indifferent (3)           59
# Strongly agree (5)        54
# Dis-agree (2)             50
# Strongly disagree (1)      5
# Name: 43 Shopping on the website gives you the sense of adventure, dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='43 Shopping on the website gives you the sense of adventure', ylabel='count'>

# %%
# For checking distribution among different categorical columns:
plt.figure(figsize=(6,7))
print(data['47 Getting value for money spent'].value_counts())
print("-"*70)
sns.countplot(data['47 Getting value for money spent'].sort_values(),palette="Set1")
# Out:
# Agree (4)             149
# Strongly agree (5)     82
# indifferent (3)        38
# Name: 47 Getting value for money spent, dtype: int64
# ----------------------------------------------------------------------
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='47 Getting value for money spent', ylabel='count'>

# %%
# For checking distribution among different categorical columns:
plt.figure(figsize=(12,10))
print(data['Easy to use website or application'].value_counts())
print("-"*70)
sns.countplot(y=data['Easy to use website or application'].sort_values(),palette="Set3")
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    64
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         44
# Amazon.in                                                       29
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                22
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Flipkart.com, Myntra.com                             19
# Paytm.com                                                       12
# Flipkart.com                                                     8
# Amazon.in, Paytm.com                                             7
# Name: Easy to use website or application, dtype: int64
# ----------------------------------------------------------------------
# <AxesSubplot:xlabel='count', ylabel='Easy to use website or application'>

# %%
# For checking distribution among different categorical columns using countPlot method:
plt.figure(figsize=(12,10))
print(data['Visual appealing web-page layout'].value_counts())
print("-"*70)
sns.countplot(y=data['Visual appealing web-page layout'].sort_values(),palette="Set2")
# Out:
# Amazon.in, Flipkart.com                                         87
# Amazon.in                                                       44
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    36
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Myntra.com                                           15
# Myntra.com                                                      15
# Flipkart.com, Myntra.com                                        15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Flipkart.com                                                    12
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                11
# Name: Visual appealing web-page layout, dtype: int64
# ----------------------------------------------------------------------
# <AxesSubplot:xlabel='count', ylabel='Visual appealing web-page layout'>

# %%
# For checking distribution among different categorical columns using countPlot method:
plt.figure(figsize=(12,10))
print(data['Wild variety of product on offer'].value_counts())
print("-"*70)
sns.countplot(y=data['Wild variety of product on offer'].sort_values(),palette="Set3")
# Out:
# Amazon.in, Flipkart.com                              130
# Amazon.in                                             43
# Amazon.in, Myntra.com                                 20
# Flipkart.com, Myntra.com                              15
# Myntra.com                                            15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     14
# Amazon.in, Flipkart.com, Paytm.com                    13
# Flipkart.com                                          12
# Paytm.com                                              7
# Name: Wild variety of product on offer, dtype: int64
# ----------------------------------------------------------------------
# <AxesSubplot:xlabel='count', ylabel='Wild variety of product on offer'>

# %%
# For checking distribution among different categorical columns using countPlot method:
plt.figure(figsize=(12,10))
print(data['Complete, relevant description information of products'].value_counts())
print("-"*70)
sns.countplot(y=data['Complete, relevant description information of products'].sort_values(),palette=None)
# Out:
# Amazon.in, Flipkart.com                                         100
# Amazon.in                                                        43
# Amazon.in, Flipkart.com, Paytm.com                               24
# Amazon.in, Paytm.com, Myntra.com                                 20
# Amazon.in, Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                14
# Snapdeal.com                                                     12
# Flipkart.com, Snapdeal.com                                       11
# Flipkart.com                                                      8
# Amazon.in, Flipkart.com, Snapdeal.com                             7
# Name: Complete, relevant description information of products, dtype: int64
# ----------------------------------------------------------------------
# ...

# %%
# For checking distribution among different categorical columns using countPlot method:
plt.figure(figsize=(12,10))
print(data['Fast loading website speed of website and application'].value_counts())
print("-"*70)
sns.countplot(y=data['Fast loading website speed of website and application'].sort_values(),palette="Set1")
# Out:
# Amazon.in                                                       51
# Amazon.in, Paytm.com                                            44
# Amazon.in, Flipkart.com, Myntra.com                             30
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    30
# Amazon.in, Flipkart.com                                         30
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com, Paytm.com                              25
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Snapdeal.com                                                    12
# Flipkart.com                                                     8
# Name: Fast loading website speed of website and application, dtype: int64
# ----------------------------------------------------------------------
# <AxesSubplot:xlabel='count', ylabel='Fast loading website speed of website and application'>

# %%
# For checking distribution among different categorical columns using countPlot method:# 
plt.figure(figsize=(12,10))
print(data['Reliability of the website or application'].value_counts())
print("-"*70)
sns.countplot(y=data['Reliability of the website or application'].sort_values(),palette="Set2")
# Out:
# Amazon.in                                            61
# Amazon.in, Flipkart.com                              50
# Amazon.in, Flipkart.com, Paytm.com                   36
# Amazon.in, Paytm.com, Myntra.com                     35
# Amazon.in, Flipkart.com, Snapdeal.com                18
# Myntra.com                                           15
# Flipkart.com                                         15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com    14
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com     13
# Paytm.com                                            12
# Name: Reliability of the website or application, dtype: int64
# ----------------------------------------------------------------------
# <AxesSubplot:xlabel='count', ylabel='Reliability of the website or application'>

# %%
# For checking distribution among different categorical columns using countPlot method:-
plt.figure(figsize=(12,10))
print(data['Perceived Trustworthiness'].value_counts())
print("-"*70)
sns.countplot(y=data['Perceived Trustworthiness'].sort_values(),palette=None)
# Out:
# Amazon.in                                                       76
# Amazon.in, Flipkart.com, Snapdeal.com                           36
# Amazon.in, Myntra.com                                           35
# Amazon.in, Flipkart.com                                         31
# Flipkart.com                                                    27
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               25
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    13
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Perceived Trustworthiness, dtype: int64
# ----------------------------------------------------------------------
# <AxesSubplot:xlabel='count', ylabel='Perceived Trustworthiness'>

# %%
# For checking distribution among different categorical columns using countPlot method:
plt.figure(figsize=(12,10))
print(data['Website is as efficient as before'].value_counts())
print("-"*70)
sns.countplot(y=data['Website is as efficient as before'].sort_values(),palette="Set2")
# Out:
# Amazon.in                             94
# Flipkart.com                          47
# Amazon.in, Flipkart.com               45
# Amazon.in, Flipkart.com, Paytm.com    25
# Amazon.in, Paytm.com                  18
# Paytm.com                             15
# Myntra.com, Snapdeal.com              14
# Snapdeal.com                          11
# Name: Website is as efficient as before, dtype: int64
# ----------------------------------------------------------------------
# <AxesSubplot:xlabel='count', ylabel='Website is as efficient as before'>

# %%
# For checking distribution among different categorical columns using countPlot method:-
plt.figure(figsize=(12,10))
print(data['Which of the Indian online retailer would you recommend to a friend?'].value_counts())
print("-"*70)
sns.countplot(y=data['Which of the Indian online retailer would you recommend to a friend?'].sort_values(),palette="Set3")
# Out:
# Amazon.in                                            79
# Amazon.in, Flipkart.com                              62
# Flipkart.com                                         39
# Amazon.in, Myntra.com                                30
# Amazon.in, Paytm.com, Myntra.com                     20
# Amazon.in, Flipkart.com, Myntra.com                  15
# Amazon.in, Paytm.com                                 13
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com    11
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64
# ----------------------------------------------------------------------
# <AxesSubplot:xlabel='count', ylabel='Which of the Indian online retailer would you recommend to a friend?'>
