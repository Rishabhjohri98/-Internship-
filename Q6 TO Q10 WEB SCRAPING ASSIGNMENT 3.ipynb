# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"chromedriver.exe")
driver.get("https://trak.in/")                                                       ## ANSWER Q-6
# Out:
# C:\Users\RISHABH JOHRI\AppData\Local\Temp\ipykernel_21328\4285723328.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"chromedriver.exe")

# %%
button = driver.find_elements(By.XPATH,'//li[@class="bs-pretty-tabs-container menu-item-has-children menu-item better-anim-fade bsm-leave"]')
driver.get(button)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentException                  Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 button = driver.find_elements(By.XPATH,'//li[@class="bs-pretty-tabs-container menu-item-has-children menu-item better-anim-fade bsm-leave"]')
# ----> 2 driver.get(button)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.get(self, url)
#     436 def get(self, url: str) -> None:
#     437     """
#     438     Loads a web page in the current browser session.
#     439     """
# --> 440     self.execute(Command.GET, {'url': url})
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     426 response = self.command_executor.execute(driver_command, params)
#     427 if response:
# --> 428     self.error_handler.check_response(response)
# ...

# %%
fund_dict = {}
fund_dict['Date'] = []
fund_dict['Startup Name'] = []
fund_dict['Industry/Vertical'] = []
fund_dict['Sub-Vertical'] = []
fund_dict['Location'] = []
fund_dict['Investor'] = []
fund_dict['Investment Type'] = []
fund_dict['Amount(in USD)'] = []

# %%
for i in range(48,51):
    driver.find_elements(By.XPATH,'//div[@id="tablepress-{}_wrapper"]/div/label/select/option[4]')

# %%
dt = driver.find_elements(By.XPATH,'//td[@class="column-2"]')
for d in dt:
        fund_dict['Date'].append(d.text)

# %%
sn = driver.find_elements(By.XPATH,'//td[@class="column-3"]')
for n in sn:
        fund_dict['Startup Name'].append(n.text)

# %%
ind = driver.find_elements(By.XPATH,'//td[@class="column-4"]')
for n in ind:
        fund_dict['Industry/Vertical'].append(n.text)

# %%
SV = driver.find_elements(By.XPATH,'//td[@class="column-5"]')
for s in SV:
        fund_dict['Sub-Vertical'].append(s.text)

# %%
loc = driver.find_elements(By.XPATH,'//td[@class="column-6"]')
for l in loc:
        fund_dict['Location'].append(l.text)

# %%
inv = driver.find_elements(By.XPATH,'//td[@class="column-7"]')
for n in inv:
        fund_dict['Investor'].append(n.text)

# %%
Investment = driver.find_elements(By.XPATH,'//td[@class="column-8"]')
for n in Investment:
        fund_dict['Investment Type'].append(n.text)

# %%
Amount = driver.find_elements(By.XPATH,'//td[@class="column-9"]')
for a in Amount:
        fund_dict['Amount'].append(n.text)

# %%
print(len(Amount),len(Investment),len(inv),len(loc),len(SV),len(ind),len(sn),len(dt))
# Out:
# 392 392 392 392 392 392 392 392

# %%
funding=pd.DataFrame({'Date':dt,'STARTUPNAME':sn,'INDUSTRY':ind,
                      'SUBVERTICAL':SV,'LOCATION':loc,'INVESTORNAME':inv,'TYPEINV':Investment,'AMOUNTS':Amount})

# %%
funding
# Out:
#                                                   Date  \
# 0    <selenium.webdriver.remote.webelement.WebEleme...
# 1    <selenium.webdriver.remote.webelement.WebEleme...
# 2    <selenium.webdriver.remote.webelement.WebEleme...
# 3    <selenium.webdriver.remote.webelement.WebEleme...
# 4    <selenium.webdriver.remote.webelement.WebEleme...
# ..                                                 ...
# 387  <selenium.webdriver.remote.webelement.WebEleme...
# 388  <selenium.webdriver.remote.webelement.WebEleme...
# 389  <selenium.webdriver.remote.webelement.WebEleme...
# 390  <selenium.webdriver.remote.webelement.WebEleme...
# 391  <selenium.webdriver.remote.webelement.WebEleme...
#
#                                            STARTUPNAME  \
# 0    <selenium.webdriver.remote.webelement.WebEleme...
# 1    <selenium.webdriver.remote.webelement.WebEleme...
# 2    <selenium.webdriver.remote.webelement.WebEleme...
# 3    <selenium.webdriver.remote.webelement.WebEleme...
# ...

# %%
driver=webdriver.Chrome(r"chromedriver.exe")                                                      ## ANSWER Q-7
# Out:
# C:\Users\RISHABH JOHRI\AppData\Local\Temp\ipykernel_1144\1698866450.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"chromedriver.exe")                                                      ## ANSWER Q-7

# %%
driver.get('https://www.digit.in/')

# %%
top_10=driver.find_elements(By.XPATH,'//div[@class="menu"]/ul/li[3]/a')

# %%
laptops=driver.find_elements(By.XPATH,'//ul[@id="top10list"]/li[2]')

# %%
best_gaming=driver.find_elements(By.XPATH,'//div[@id="laptops"]/a[3]')
driver.get(best_gaming.get_attribute('href'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [43], in <cell line: 2>()
#       1 best_gaming=driver.find_elements(By.XPATH,'//div[@id="laptops"]/a[3]')
# ----> 2 driver.get(best_gaming.get_attribute('href'))
#
# AttributeError: 'list' object has no attribute 'get_attribute'

# %%
name = []
OS = []
display = []
processor = []

# %%
names=driver.find_elements(By.XPATH,'//div[@class="TopNumbeHeading"]')
for i in names:
    name.append(i.text)

# %%
df=pd.DataFrame({"Name":name})

# %%
df
# Out:
#                                                 Name
# 0                           1.\nMSI Titan GT77-12UHS
# 1                               2.\nAlienware X17 R2
# 2          3.\nAcer Predator Triton 500 SE PT516-52s
# 3                        4.\nOmen By HP (16-B1371TX)
# 4  5.\nAcer Predator Helios 300 AN515-45 (NH.QBRSI.0
# 5                     6.\nMSI Delta 15 (A5EFK-083IN)
# 6                        7.\nOmen By HP (16-C0141AX)
# 7              8.\nLenovo Legion 5i Pro (82RF00MGIN)
# 8  9.\nAlienware M15 R5 Ryzen Edition Icc-C780001win
# 9              10.\nLenovo Slim 7 Gen 6 (82K8002JIN)

# %%
print(len(name))
# Out:
# 10

# %%
os=driver.find_elements(By.XPATH,'//div[@class="Wrap-pop"]')
for i in os:
    OS.append(i.text)

# %%
print(len(OS))
# Out:
# 40

# %%
displays=driver.find_elements(By.XPATH,'//div[@class="product-detail"]')
for i in displays:
    display.append(i.text)

# %%
print(len(displays))
# Out:
# 10

# %%
processors=driver.find_elements(By.XPATH,'//div[@class="value"]')
for i in processors:
    processor.append(i.text)

# %%
print(len(processor))
# Out:
# 40

# %%
full_specs=[]
urls=driver.find_elements(By.XPATH,'//div[@class="full-specs"]')
for i in urls:
    if i.get_attribute('data-href'):
        full_specs.append(i.get_attribute('data-href'))

# %%
df=pd.DataFrame({"Name":name,"Display":display})

# %%
df1=pd.DataFrame({"Operating System":OS,"PROCESSOR OF LAPTOP":processor})

# %%
df1
# Out:
#                                      Operating System  \
# 0                                  Windows 11 Home OS
# 1                         17.3" (3840 x 2160) Display
# 2       12th Gen Intel Core i9-12900HX | NA Processor
# 3                          2 TB SSD/64 GB DDR5 Memory
# 4                                  Windows 11 Home OS
# 5                         17.3" (1920 x 1080) Display
# 6     12th Gen Intel Core i9-12900H | 5 GHz Processor
# 7                          1 TB SSD/32 GB DDR5 Memory
# 8                                  Windows 11 Home OS
# 9                           16" (2560 x 1600) Display
# 10  12th Gen Intel Core i7-12700H | 3.50 GHz Proce...
# 11                         2 TB SSD/32 GB DDR5 Memory
# 12                                 Windows 11 Home OS
# 13                        16.1" (2560 x 1440) Display
# 14  12th Gen Intel Core i7-12700H | 4.7 GHz Processor
# 15                          1 TB SSD/8 GB DDR5 Memory
# ...

# %%
df
# Out:
#                                                 Name  \
# 0                           1.\nMSI Titan GT77-12UHS
# 1                               2.\nAlienware X17 R2
# 2          3.\nAcer Predator Triton 500 SE PT516-52s
# 3                        4.\nOmen By HP (16-B1371TX)
# 4  5.\nAcer Predator Helios 300 AN515-45 (NH.QBRSI.0
# 5                     6.\nMSI Delta 15 (A5EFK-083IN)
# 6                        7.\nOmen By HP (16-C0141AX)
# 7              8.\nLenovo Legion 5i Pro (82RF00MGIN)
# 8  9.\nAlienware M15 R5 Ryzen Edition Icc-C780001win
# 9              10.\nLenovo Slim 7 Gen 6 (82K8002JIN)
#
#                                              Display
# 0  Windows 11 Home OS\n17.3" (3840 x 2160) Displa...
# 1  Windows 11 Home OS\n17.3" (1920 x 1080) Displa...
# 2  Windows 11 Home OS\n16" (2560 x 1600) Display\...
# 3  Windows 11 Home OS\n16.1" (2560 x 1440) Displa...
# 4  Windows 11 Home OS\n15.6" (2560 x 1440) Displa...
# 5  Windows 11 Home OS\n15.6" (1920 x 1080) Displa...
# ...

# %%
driver=webdriver.Chrome(r"chromedriver.exe")                                     # ANSWER Q-8
# Out:
# C:\Users\RISHABH JOHRI\AppData\Local\Temp\ipykernel_1144\64258346.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"chromedriver.exe")                                     # ANSWER Q-8

# %%
url = "https://www.forbes.com/?sh=69e6b8c92254"
driver.get(url)
time.sleep(3)

# %%
button = driver.find_elements(By.XPATH,'//button[@class="icon--hamburger"]')
button
time.sleep(1)

# %%
bill = driver.find_elements(By.XPATH,"/html/body/div[1]/header/nav/div[3]/ul/li[1]")
bill
time.sleep(1)

# %%
world_bill= driver.find_elements(By.XPATH,"/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a")
world_bill
time.sleep(1)

# %%
Rank = []
Person_Name = []
total_net_worth = []
Age = []
citizenship = []
Source = []
industry = []

# %%
rank_tags= driver.find_elements(By.XPATH,'//span[@class="byline__author-type"]')
for rank in rank_tags:
        Rank.append(rank.text)

# %%
name_tags= driver.find_elements(By.XPATH,'//a[@class="byline__author-name"]')
for name in name_tags:
        Person_Name.append(name.text)

# %%
print(len(Rank),len(Person_Name))
# Out:
# 16 16

# %%
citytags= driver.find_elements(By.XPATH,'//div[@class="countryOfCitizenship"]')
for cit in citytags:
    citizenship.append(cit.text)

# %%
sour_tags= driver.find_elements(By.XPATH,'//span[@class="source-text"]')
for sour in sour_tags:
    Source.append(sour.text)

# %%
net_tags= driver.find_elements(By.XPATH,'//div[@class="billions-amount"]')
for net in net_tags:
    total_net_worth.append(net.text)

# %%
next_button = driver.find_elements(By.XPATH,'//svg[@class="fs-icon fs-icon--arrow-right"]')
next_button
# Out:
# []

# %%
print(len(total_net_worth),len(citizenship))
# Out:
# 2 200

# %%
Billionaires=pd.DataFrame({})
Billionaires['Rank'] = Rank
Billionaires['Names'] = Person_Name

# %%
Billionaires
# Out:
#             Rank                 Names
# 0   Forbes Staff         Dan Alexander
# 1   Forbes Staff             John Kang
# 2   Forbes Staff        Kerry A. Dolan
# 3   Forbes Staff       Jonathan Burgos
# 4   Forbes Staff       Giacomo Tognini
# 5   Forbes Staff    Carlie Porterfield
# 6   Forbes Staff      Russell Flannery
# 7   Forbes Staff      Russell Flannery
# 8   Forbes Staff  Michael del Castillo
# 9   Forbes Staff          Zach Everson
# 10  Forbes Staff       Giacomo Tognini
# 11  Forbes Staff          Jayde Cheung
# 12  Forbes Staff        Rachel Sandler
# 13  Forbes Staff      Russell Flannery
# 14  Forbes Staff      Russell Flannery
# 15  Forbes Staff          Zach Everson

# %%
Billdf=pd.DataFrame({'CITIZENSHIP':citizenship,})

# %%
Billdf
# Out:
#        CITIZENSHIP
# 0    United States
# 1    United States
# 2           France
# 3    United States
# 4    United States
# ..             ...
# 195         Brazil
# 196  United States
# 197  United States
# 198  United States
# 199          China
#
# [200 rows x 1 columns]

# %%
driver=webdriver.Chrome("chromedriver.exe")
time.sleep(2)                                                                      # ANSWER Q-9
# Out:
# C:\Users\RISHABH JOHRI\AppData\Local\Temp\ipykernel_1144\436801147.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("chromedriver.exe")

# %%
url = "https://www.youtube.com/"
driver.get(url)
time.sleep(2)

# %%
search_bar = driver.find_element_by_id('search')
search_bar.send_keys("GOT")
time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [98], in <cell line: 1>()
# ----> 1 search_bar = driver.find_element_by_id('search')
#       2 search_bar.send_keys("GOT")
#       3 time.sleep(1)
#
# AttributeError: 'WebDriver' object has no attribute 'find_element_by_id'

# %%
search_btn = driver.find_element_by_id("search-icon-legacy")  
search_btn
time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [103], in <cell line: 1>()
# ----> 1 search_btn = driver.find_element_by_id("search-icon-legacy")
#       2 search_btn
#       3 time.sleep(1)
#
# AttributeError: 'WebDriver' object has no attribute 'find_element_by_id'

# %%
link_click = driver.find_elements(By.XPATH,'//span[@class="style-scope ytd-video-meta-block"]')
link_click
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="40bb48f01c31799a300b5ac5e59e1666", element="d1a2093b-f4e3-4f15-9d82-e31a84aa6210")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="40bb48f01c31799a300b5ac5e59e1666", element="015bb9bb-84ef-4fec-8d28-c838ce9a0d0f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="40bb48f01c31799a300b5ac5e59e1666", element="03bb649b-bd4f-4976-a0f3-1847dfb7353e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="40bb48f01c31799a300b5ac5e59e1666", element="69bb5a8e-1339-4dae-a1df-71b34b1d4678")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="40bb48f01c31799a300b5ac5e59e1666", element="68620184-744e-49ee-abd7-01b36dc3389e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="40bb48f01c31799a300b5ac5e59e1666", element="840c898f-be5e-4712-9155-d65604300c34")>,
# ...

# %%
comments = []
time = []
Time = []
Likes = []
No_of_Likes = []

# %%
cm_tags = driver.find_elements(By.XPATH,'//span[@class="style-scope yt-formatted-string"]')
for cm in cm_tags[0:500]:
    if cm.text is None:
        comments.append("--")
    else:
        comments.append(cm.text)

# %%
tm_tags = driver.find_elements(By.XPATH,'//a[@class="yt-simple-endpoint style-scope yt-formatted-string"]')
for tm in tm_tags[0:500]:
    Time.append(tm.text)

for i in range(0,len(Time),2):
    time.append(Time[i])

# %%
like_tags = driver.find_elements(By.XPATH,'//span[@class="style-scope ytd-comment-action-buttons-renderer"]')
for like in like_tags[0:500]:
    Likes.append(like.text)
    
for i in range(1,len(Likes),2):
    No_of_Likes.append(Likes[i])

# %%
print(len(comments),len(time),len(Time),len(Likes),len(No_of_Likes))
# Out:
# 198 215 258 80 60

# %%
dataframe=pd.DataFrame({'Comments':comments})

# %%
dataframe
# Out:
#                                               Comments
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 193  This masterpiece will always attached to my he...
# 194                                                  ️
# 195                                                  ️
# 196                    Emotion = Arijit magical voice
# 197                                                  ️
#
# [198 rows x 1 columns]

# %%
df2=pd.DataFrame({'TIME':time})
df2
# Out:
#             TIME
# 0
# 1
# 2
# 3
# 4
# ..           ...
# 210  1 month ago
# 211  1 month ago
# 212   5 days ago
# 213   2 days ago
# 214  1 month ago
#
# [215 rows x 1 columns]

# %%
df3=pd.DataFrame({"Comment Upvotes":No_of_Likes})

# %%
df3
# Out:
#    Comment Upvotes
# 0                9
# 1                5
# 2              152
# 3                2
# 4              190
# 5                4
# 6              279
# 7               10
# 8               25
# 9                6
# 10              94
# 11              48
# 12              83
# 13              79
# 14              10
# 15              78
# 16
# 17              78
# 18              56
# 19
# 20               9
# 21               5
# 22             152
# 23               2
# 24             190
# 25               4
# 26             279
# 27              10
# 28              25
# 29               6
# 30              94
# 31              48
# 32              83
# 33              79
# 34              10
# 35              78
# 36
# 37              78
# 38              56
# 39
# 40               9
# 41               5
# 42             152
# 43               2
# 44             190
# 45               4
# 46             279
# 47              10
# 48              25
# ...

# %%
driver=webdriver.Chrome("chromedriver.exe")
time.sleep(2)                                                                    ## ANSWER Q-10
# Out:
# C:\Users\RISHABH JOHRI\AppData\Local\Temp\ipykernel_21328\4233197207.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("chromedriver.exe")

# %%
url = "https://www.hostelworld.com/"
driver.get(url)
time.sleep(5)

# %%
search_loc = driver.find_element(By.id,'search-input-field')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 search_loc = driver.find_element(By.id,'search-input-field')
#
# AttributeError: type object 'By' has no attribute 'id'

# %%
search_loc.send_keys("London")
time.sleep(5)

# %%
london = driver.find_elements(By.XPATH,'/html/body/div[1]/div/div/div[1]/div[1]/div/div[2]/div[4]/div/div[2]/div/div[1]/div/div/ul/li[2]/div')
london
time.sleep(5)

# %%
search_btn = driver.find_element_by_id('search-button')

# %%
hostel_name = []
distance = []
dorms_price = []
rating = []
reviews = []
over_all = []
facilities = []
description =[]
product_url = []

# %%
for i in driver.find_elements(By.XPATH,'//div[@class = "pagination-item pagination-current" or @class="pagination-item"]'):
    i.click()
    time.sleep(4)

# %%
hostel_name=driver.find_elements(By.XPATH,'//h2[@class="title title-6"]')
for i in hostel_name:
    hostel=i.text
    hostel_name.append(hostel)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [127], in <cell line: 2>()
#       1 hostel_name=driver.find_elements(By.XPATH,'//h2[@class="title title-6"]')
#       2 for i in hostel_name:
# ----> 3     hostel=i.text
#       4     hostel_name.append(hostel)
#
# AttributeError: 'str' object has no attribute 'text'

# %%
print(len(hostel_name))
# Out:
# 60

# %%
distance=driver.find_elements(By.XPATH,'//span[@class="description"]')
for i in distance:
    dis=i.text
    distance.append(dis)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [129], in <cell line: 2>()
#       1 distance=driver.find_elements(By.XPATH,'//span[@class="description"]')
#       2 for i in distance:
# ----> 3     dis=i.text
#       4     distance.append(dis)
#
# AttributeError: 'str' object has no attribute 'text'

# %%
print(len(distance))
# Out:
# 60

# %%
rating=driver.find_elements(By.XPATH,'//div[@class="score orange big"]')
for i in rating:
    rate=i.text
    rating.append(rate)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [131], in <cell line: 2>()
#       1 rating=driver.find_elements(By.XPATH,'//div[@class="score orange big"]')
#       2 for i in rating:
# ----> 3     rate=i.text
#       4     rating.append(rate)
#
# AttributeError: 'str' object has no attribute 'text'

# %%
print(len(rating))
# Out:
# 48

# %%
reviews=driver.find_elements(By.XPATH,'//div[@class="review-notes body-2"]')
for i in reviews:
    rev=i.text
    reviews.append(rev)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [135], in <cell line: 2>()
#       1 reviews=driver.find_elements(By.XPATH,'//div[@class="review-notes body-2"]')
#       2 for i in reviews:
# ----> 3     rev=i.text
#       4     reviews.append(rev)
#
# AttributeError: 'str' object has no attribute 'text'

# %%
print(len(reviews))
# Out:
# 20

# %%
description=driver.find_elements(By.XPATH,'//div[@class="content collapse-content"]')
for i in description:
    des=i.text
    description.append(des)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [163], in <cell line: 2>()
#       1 description=driver.find_elements(By.XPATH,'//div[@class="content collapse-content"]')
#       2 for i in description:
# ----> 3     des=i.text
#       4     description.append(des)
#
# AttributeError: 'str' object has no attribute 'text'

# %%
print(len(description))
# Out:
# 4

# %%
facilities=driver.find_elements(By.XPATH,'//div[@class="facilities-container"]')
for i in facilities:
    fac=i.text
    facilities.append(fac)

# %%
print(len(facilities))
# Out:
# 0

# %%
dorms_price=driver.find_elements(By.XPATH,'//div[@class="price"]')
for i in dorms_price:
    dorm=i.text
    dorms_price.append(dorm)

# %%
print(len(dorms_price))
# Out:
# 12

# %%
over_all=driver.find_elements(By.XPATH,'//div[@class="score orange medium"]')
for i in over_all:
    ovr=i.text
    over_all.append(ovr)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [154], in <cell line: 2>()
#       1 over_all=driver.find_elements(By.XPATH,'//div[@class="score orange medium"]')
#       2 for i in over_all:
# ----> 3     ovr=i.text
#       4     over_all.append(ovr)
#
# AttributeError: 'str' object has no attribute 'text'

# %%
print(len(over_all))
# Out:
# 18

# %%
product_url = driver.find_elements(By.XPATH,'//div[@class="prices-col"]')
for i in product_url:
        url.append(i.get_attribute("href"))
        
for i in url:
    driver.get(i)
    time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [25], in <cell line: 2>()
#       1 product_url = driver.find_elements(By.XPATH,'//div[@class="prices-col"]')
#       2 for i in product_url:
# ----> 3         url.append(i.get_attribute("href"))
#       5 for i in url:
#       6     driver.get(i)
#
# AttributeError: 'str' object has no attribute 'append'

# %%
print(len(product_url))
# Out:
# 20

# %%
dataframe=pd.DataFrame({"NAME":hostel_name,"DISTANCE":distance})

# %%
dataframe
# Out:
#                                                  NAME  \
# 0   <selenium.webdriver.remote.webelement.WebEleme...
# 1   <selenium.webdriver.remote.webelement.WebEleme...
# 2   <selenium.webdriver.remote.webelement.WebEleme...
# 3   <selenium.webdriver.remote.webelement.WebEleme...
# 4   <selenium.webdriver.remote.webelement.WebEleme...
# 5   <selenium.webdriver.remote.webelement.WebEleme...
# 6   <selenium.webdriver.remote.webelement.WebEleme...
# 7   <selenium.webdriver.remote.webelement.WebEleme...
# 8   <selenium.webdriver.remote.webelement.WebEleme...
# 9   <selenium.webdriver.remote.webelement.WebEleme...
# 10  <selenium.webdriver.remote.webelement.WebEleme...
# 11  <selenium.webdriver.remote.webelement.WebEleme...
# 12  <selenium.webdriver.remote.webelement.WebEleme...
# 13  <selenium.webdriver.remote.webelement.WebEleme...
# 14  <selenium.webdriver.remote.webelement.WebEleme...
# 15  <selenium.webdriver.remote.webelement.WebEleme...
# ...

# %%
data1=pd.DataFrame({"URL":product_url})

# %%
data1
# Out:
#                                                   URL
# 0   <selenium.webdriver.remote.webelement.WebEleme...
# 1   <selenium.webdriver.remote.webelement.WebEleme...
# 2   <selenium.webdriver.remote.webelement.WebEleme...
# 3   <selenium.webdriver.remote.webelement.WebEleme...
# 4   <selenium.webdriver.remote.webelement.WebEleme...
# 5   <selenium.webdriver.remote.webelement.WebEleme...
# 6   <selenium.webdriver.remote.webelement.WebEleme...
# 7   <selenium.webdriver.remote.webelement.WebEleme...
# 8   <selenium.webdriver.remote.webelement.WebEleme...
# 9   <selenium.webdriver.remote.webelement.WebEleme...
# 10  <selenium.webdriver.remote.webelement.WebEleme...
# 11  <selenium.webdriver.remote.webelement.WebEleme...
# 12  <selenium.webdriver.remote.webelement.WebEleme...
# 13  <selenium.webdriver.remote.webelement.WebEleme...
# 14  <selenium.webdriver.remote.webelement.WebEleme...
# 15  <selenium.webdriver.remote.webelement.WebEleme...
# ...

# %%
Hostel.to_csv("London_Hostels.csv")
